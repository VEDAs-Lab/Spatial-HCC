# %% [markdown]
# # Notebook Index
#
# Run order:
# 1. `01_scRNA_reference_processing.ipynb`
# 2. `02_visium_spot_scoring.ipynb`
# 3. `03_core_spatial_pipeline.ipynb`
# 4. `04_continuous_torus_extension.ipynb` (optional)
# 5. `05_tcga_survival_validation.ipynb`
#
# Archive notebooks are included so no code is lost.

# %% [markdown]
# ## Dedup strategy
#
# Only one canonical branch is kept in the main run path. Repetitive/alternative cells were moved to archive notebooks.
